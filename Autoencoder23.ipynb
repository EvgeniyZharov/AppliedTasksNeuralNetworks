# %% [markdown]
# # Импорт библиотек

# %%
from tensorflow.keras.models import Model, Sequential

from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from tensorflow.keras.datasets import mnist, fashion_mnist 
from tensorflow.keras.callbacks import LambdaCallback

import matplotlib.pyplot as plt 
from tensorflow.keras.preprocessing import image
import numpy as np  
import pandas as pd 
from PIL import Image 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler 

import os 
from google.colab import drive 
import time, random
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# # Подключение к Гугл Диску

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Вспомогательные функции

# %% [markdown]
# ## Функция создания автокодировщика

# %%
def baseAutoencoder(shape=(112,80,1)): 
    img_input = Input((shape)) 

    x = Conv2D(32, (3, 3), padding='same', activation='relu')(img_input) 
    x = BatchNormalization()(x) 
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 
    x = MaxPooling2D()(x) 

    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x) 
    z = MaxPooling2D()(x) 
    

    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same', activation='relu')(z) 
    x = BatchNormalization()(x) 
    
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 
     
    x = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 

    x = Conv2D(shape[-1], (3, 3), activation='sigmoid', padding='same')(x)

    model = Model(img_input, x)
    model.compile(optimizer=Adam(lr=0.0001),
                  loss='mean_squared_error')

    return model

# %% [markdown]
# ## Функция вывода изображений

# %%
def plotImages(xTrain, pred, shape=(112, 80)): 
  n = 5 
  plt.figure(figsize=(14, 7)) 
  for i in range(n): 
      index = np.random.randint(0, pred.shape[0]) 
 
      ax = plt.subplot(2, n, i + 1) 
      plt.imshow(xTrain[index].reshape(shape)) 
      plt.gray() 
      ax.get_xaxis().set_visible(False)  
      ax.get_yaxis().set_visible(False) 
 
      ax = plt.subplot(2, n, i + 1 + n) 
      plt.imshow(pred[index].reshape(shape))   
      plt.gray() 
      ax.get_xaxis().set_visible(False) 
      ax.get_yaxis().set_visible(False) 
  plt.show()

# %% [markdown]
# ## Функция получения средней квадратичной ошибки

# %%
def getMSE(x1, x2): 
  x1 = x1.flatten() 
  x2 = x2.flatten() 
  delta = x1 - x2 
  return sum(delta ** 2) / len(delta)

# %%
x1 = np.array([1, 1, 1]) 
x2 = np.array([1, 1, 1]) 
print(getMSE(x1,x2))
# Out:
# 0.0

# %% [markdown]
# ## Функция создания шума

# %%
def addNoise(x, noiseVal):
  noise = np.random.normal(loc=0.5, scale=0.5, size=x.shape)
  
  return np.clip(x + noiseVal * noise, 0., 1.)

# %% [markdown]
# ## Функция для загрузки изображений

# %%
def load_images(images_dir, img_height, img_width): 
  list_images = []
  for img in os.listdir(images_dir):
    list_images.append(image.img_to_array(image.load_img(os.path.join(images_dir, img), target_size=(img_height, img_width), color_mode='grayscale')))
  return np.array(list_images)

# %% [markdown]
# ## Функция автокодировщика для подавления шума

# %%
def denoiseAutoencoder(level=1):

  if level not in [1, 2, 3]:
    level = 1

  img_input = Input((112,80,1))

  if level == 1:
    

    x = Conv2D(32, (3, 3), strides=2, activation='relu', padding='same')(img_input)
    x = Conv2D(64, (3, 3), strides=2, activation='relu', padding='same')(x)
    x = Conv2D(128, (3, 3), strides=2, activation='relu', padding='same')(x)
    x = Conv2D(256, (3, 3), strides=2, activation='relu', padding='same')(x)
    x = Flatten()(x)
    z = Dense(256, activation='relu')(x)
    x = Dense(7*5*256, activation='relu')(z)
    x = Reshape((7,5,256))(x)
    x = Conv2DTranspose(256, (3, 3), strides=2, padding='same')(x)
    x = Conv2DTranspose(128, (3, 3), strides=2, padding='same')(x)
    x = Conv2DTranspose(64, (3, 3), strides=2, padding='same')(x)
    x = Conv2DTranspose(32, (3, 3), strides=2, padding='same')(x)

  if level == 2:

    x = Conv2D(32, (3, 3), strides=2, activation='relu', padding='same')(img_input)
    x = Conv2D(64, (3, 3), strides=2, activation='relu', padding='same')(x)
    x = Conv2D(128, (3, 3), strides=2, activation='relu', padding='same')(x)
    x = Conv2D(256, (3, 3), strides=2, activation='relu', padding='same')(x)
    x = Flatten()(x)
    z = Dense(256, activation='relu')(x)
    x = Dense(7*5*256, activation='relu')(z)
    x = Reshape((7,5,256))(x)
    x = Conv2DTranspose(256, (3, 3), strides=2, padding='same')(x)
    x = Conv2DTranspose(128, (3, 3), strides=2, padding='same')(x)
    x = Conv2DTranspose(64, (3, 3), strides=2, padding='same')(x)
    x = Conv2DTranspose(32, (3, 3), strides=2, padding='same')(x)

  if level == 3:

    x = Conv2D(8, (3, 3), strides=2, activation='relu', padding='same')(img_input)
    x = Conv2D(16, (3, 3), strides=2, activation='relu', padding='same')(x)
    x = Conv2D(32, (3, 3), strides=2, activation='relu', padding='same')(x)
    x = Conv2D(64, (3, 3), strides=2, activation='relu', padding='same')(x)
    x = Flatten()(x)
    z = Dense(64, activation='relu')(x)
    x = Dense(7*5*64, activation='relu')(z)
    x = Reshape((7,5,64))(x)
    x = Conv2DTranspose(64, (3, 3), strides=2, padding='same')(x)
    x = Conv2DTranspose(32, (3, 3), strides=2, padding='same')(x)
    x = Conv2DTranspose(16, (3, 3), strides=2, padding='same')(x)
    x = Conv2DTranspose(8, (3, 3), strides=2, padding='same')(x)

  x = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

  model = Model(img_input, x)
  model.compile(optimizer='adam',
                loss='mse')
  model.summary()

  return model

# %% [markdown]
# # Автокодировщики для подавления шума

# %% [markdown]
# ## Загрузка базы лиц

# %%
# !unzip -q '/content/drive/MyDrive/Lessons/Lesson9/facez.zip' -d "/content/facez"
# Out:
# replace /content/facez/1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
images_dir = '/content/facez'
img_height = 112
img_width = 80

# %%
cur_time = time.time()
xTrain_imag = load_images(images_dir, img_height, img_width)
print ('Время загрузки: ', round(time.time()-cur_time, 2), 'с', sep='')
# Out:
# Время загрузки: 36.7с

# %%
xTrain_img = xTrain_imag/255

# %%
xTrain_img.shape
# Out:
# (5018, 112, 80, 1)

# %%
plt.imshow(xTrain_img[np.random.randint(0, xTrain_img.shape[0])].reshape(112,80), cmap='gray')
plt.show()

# %% [markdown]
# ## Третий автокодировщик для подавления шума

# %%
noisedXTrainFace = addNoise(xTrain_img, 0.05)
plotImages(xTrain_img, noisedXTrainFace)

# %%
modelDenoiseFace = denoiseAutoencoder(level=2)

modelDenoiseFace.fit(noisedXTrainFace[:4700], xTrain_img[:4700], epochs=50, batch_size=100, validation_data = (noisedXTrainFace[4700:], xTrain_img[4700:]))
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 112, 80, 1)]      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 40, 32)        320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 20, 64)        18496
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 10, 128)       73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 5, 256)         295168
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8960)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               2294016
# _________________________________________________________________
# dense_3 (Dense)              (None, 8960)              2302720
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 5, 256)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 14, 10, 256)       590080
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 20, 128)       295040
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 56, 40, 64)        73792
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 112, 80, 32)       18464
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 112, 80, 1)        289
# =================================================================
# Total params: 5,962,241
# Trainable params: 5,962,241
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 47/47 [==============================] - 156s 3s/step - loss: 0.0509 - val_loss: 0.0318
# Epoch 2/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0227 - val_loss: 0.0170
# Epoch 3/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0153 - val_loss: 0.0138
# Epoch 4/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0124 - val_loss: 0.0115
# Epoch 5/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0110 - val_loss: 0.0105
# Epoch 6/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 7/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0095 - val_loss: 0.0092
# Epoch 8/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0088 - val_loss: 0.0086
# Epoch 9/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 10/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0084 - val_loss: 0.0082
# Epoch 11/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0075 - val_loss: 0.0077
# Epoch 12/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 13/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 14/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 15/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0066 - val_loss: 0.0072
# Epoch 16/50
# 47/47 [==============================] - 155s 3s/step - loss: 0.0065 - val_loss: 0.0071
# Epoch 17/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0063 - val_loss: 0.0071
# Epoch 18/50
# 47/47 [==============================] - 153s 3s/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 19/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 20/50
# 47/47 [==============================] - 153s 3s/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 21/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0058 - val_loss: 0.0065
# Epoch 22/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0057 - val_loss: 0.0063
# Epoch 23/50
# 47/47 [==============================] - 153s 3s/step - loss: 0.0056 - val_loss: 0.0064
# Epoch 24/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0055 - val_loss: 0.0063
# Epoch 25/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 26/50
# 47/47 [==============================] - 153s 3s/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 27/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0053 - val_loss: 0.0064
# Epoch 28/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0052 - val_loss: 0.0060
# Epoch 29/50
# 47/47 [==============================] - 153s 3s/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 30/50
# 47/47 [==============================] - 153s 3s/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 31/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0050 - val_loss: 0.0059
# Epoch 32/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 33/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0049 - val_loss: 0.0058
# Epoch 34/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 35/50
# 47/47 [==============================] - 154s 3s/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 36/50
#  3/47 [>.............................] - ETA: 2:21 - loss: 0.0048

# %%
predFaceDenoise = modelDenoiseFace.predict(noisedXTrainFace[:4000]) 
predFaceDenoise = predFaceDenoise * 255   
predFaceDenoise = predFaceDenoise.astype('uint8')

# %%
plotImages(noisedXTrainFace, predFaceDenoise)

# %%
plotImages(xTrain_img, predFaceDenoise)

# %%
errFace = [getMSE(xTrain_img[i], predFace[i] / 255) for i in range(len(predFace))]
print("Средняя ошибка на Лицах:", round(sum(errFace) / len(errFace), 4))
print("Минимальная ошибка на Лицах:", round(min(errFace),4))

# %%
del modelDenoiseFace

# %% [markdown]
# # Создание и обучение автокодировщика для работы с Fashion mnist

# %% [markdown]
# ## Подготовка данных

# %%
(xTrainMnistF, yTrainMnistF), (xTestMnistF, yTestMnistF) = fashion_mnist.load_data()
xTrainMnistF = xTrainMnistF.astype('float32')/255
xTrainMnistF = xTrainMnistF.reshape(xTrainMnistF.shape[0], 28, 28, 1)

# %%
n = 100
plt.imshow(xTrainMnistF[n].reshape((28,28)), cmap='gray')
plt.show()

# %%
modelAutoFashionMnist = baseAutoencoder((28,28,1))

# %%
modelAutoMnist.summary()

# %%
utils.plot_model(modelAutoMnist, dpi=60, show_shapes=True)

# %%
history = modelAutoMnist.fit(xTrainMnistF, xTrainMnistF, epochs=20, batch_size=256, validation_data = (xTestMnist, xTestMnist))

# %%
plt.figure(figsize=(14,7))
plt.plot(history.history['loss'][10:], 
         label='Средняя абсолютная ошибка на обучающем наборе')
plt.plot(history.history['val_loss'][10:], 
         label='Средняя абсолютная ошибка на проверочном наборе')
plt.ylabel('Средняя ошибка')
plt.legend()
plt.show()

# %%
predMnistF = modelAutoMnist.predict(xTrainMnistF)
predMnistF = predMnistF * 255
predMnistF = predMnistF.astype('uint8')

# %%
errF = [getMSE(xTrainMnistF[i], predMnistF[i] / 255) for i in range(len(predMnistF))]
print("Средняя ошибка на Mnist:", round(sum(err1) / len(err1), 4))
print("Средняя ошибка на одежде:", round(sum(errF) / len(errF), 4))
print()
print("Максимальная ошибка на Mnist:", round(max(err1),4))
print("Минимальная ошибка на одежде:", round(min(errF),4))

# %% [markdown]
# ## Третий автокодировщик для подавления шума

# %%
noisedXTrainFace = addNoise(xTrain_img, 0.05)
plotImages(xTrain_img, noisedXTrainFace)

# %%
modelDenoiseFace = denoiseAutoencoder(level=2)

modelDenoiseFace.fit(noisedXTrainFace[:4700], xTrain_img[:4700], epochs=50, batch_size=100, validation_data = (noisedXTrainFace[4700:], xTrain_img[4700:]))
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 112, 80, 1)]      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 40, 32)        320
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 20, 64)        18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 10, 128)       73856
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 5, 256)         295168
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8960)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               2294016
# _________________________________________________________________
# dense_3 (Dense)              (None, 8960)              2302720
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 5, 256)         0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 14, 10, 256)       590080
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 28, 20, 128)       295040
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 56, 40, 64)        73792
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 112, 80, 32)       18464
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 112, 80, 1)        289
# =================================================================
# Total params: 5,962,241
# Trainable params: 5,962,241
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0541 - val_loss: 0.0357
# Epoch 2/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0230 - val_loss: 0.0179
# Epoch 3/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0151 - val_loss: 0.0132
# Epoch 4/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0126 - val_loss: 0.0123
# Epoch 5/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0112 - val_loss: 0.0105
# Epoch 6/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 7/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0093 - val_loss: 0.0092
# Epoch 8/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 9/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 10/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0081 - val_loss: 0.0080
# Epoch 11/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0076 - val_loss: 0.0080
# Epoch 12/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0074 - val_loss: 0.0077
# Epoch 13/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 14/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0070 - val_loss: 0.0073
# Epoch 15/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 16/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 17/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0064 - val_loss: 0.0070
# Epoch 18/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0063 - val_loss: 0.0069
# Epoch 19/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 20/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 21/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 22/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 23/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0057 - val_loss: 0.0064
# Epoch 24/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0057 - val_loss: 0.0064
# Epoch 25/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 26/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 27/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 28/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 29/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 30/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0052 - val_loss: 0.0060
# Epoch 31/50
# 47/47 [==============================] - 162s 3s/step - loss: 0.0051 - val_loss: 0.0062
# Epoch 32/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 33/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0051 - val_loss: 0.0059
# Epoch 34/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0050 - val_loss: 0.0062
# Epoch 35/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0050 - val_loss: 0.0058
# Epoch 36/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0049 - val_loss: 0.0058
# Epoch 37/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0049 - val_loss: 0.0058
# Epoch 38/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 39/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0049 - val_loss: 0.0058
# Epoch 40/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 41/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0047 - val_loss: 0.0059
# Epoch 42/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 43/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0046 - val_loss: 0.0058
# Epoch 44/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 45/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0046 - val_loss: 0.0060
# Epoch 46/50
# 47/47 [==============================] - 159s 3s/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 47/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0045 - val_loss: 0.0056
# Epoch 48/50
# 47/47 [==============================] - 161s 3s/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 49/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0044 - val_loss: 0.0056
# Epoch 50/50
# 47/47 [==============================] - 160s 3s/step - loss: 0.0044 - val_loss: 0.0056

# %%
predFaceDenoise = modelDenoiseFace.predict(noisedXTrainFace[:4000]) 
predFaceDenoise = predFaceDenoise * 255   
predFaceDenoise = predFaceDenoise.astype('uint8')

# %%
plotImages(noisedXTrainFace, predFaceDenoise)

# %%
plotImages(xTrain_img, predFaceDenoise)

# %%
errFace = [getMSE(xTrain_img[i], predFace[i] / 255) for i in range(len(predFace))]
print("Средняя ошибка на Лицах:", round(sum(errFace) / len(errFace), 4))
print("Минимальная ошибка на Лицах:", round(min(errFace),4))
# Out:
# Средняя ошибка на Лицах: 0.0044
# Минимальная ошибка на Лицах: 0.0009

# %%
del modelDenoiseFace
